# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_pickle('./data/music.pkl')

# %%
df.head()
# Out:
#    genre      artist_name                                         track_name  \
# 0  opera   giuseppe verdi  stiffelio, act iii: ei fugge! … lina, pensai c...
# 1  opera  giacomo puccini  madama butterfly / act 1: ... e soffitto e pareti
# 2  opera  giacomo puccini      turandot / act 2: gloria, gloria, o vincitore
# 3  opera   giuseppe verdi       rigoletto, act iv: venti scudi hai tu detto?
# 4  opera   giuseppe verdi           don carlo / act 4: "ella giammai m'amò!"
#
#                  track_id popularity acousticness danceability duration_ms  \
# 0  7EsKYeHtTc4H4xWiTqSVZA         21        0.986        0.313      490867
# 1  7MfmRBvqaW0I6UTxXnad8p         18        0.972         0.36      176797
# 2  7pBo1GDhIysyUMFXiDVoON         10        0.935        0.168      266184
# 3  02mvYZX5aKNzdqEo6jF20m         17        0.961         0.25      288573
# 4  03TW0jwGMGhUabAjOpB1T9         19        0.985        0.142      629760
#
# ...

# %%
df_df = df.loc[df['valence'] != '0.0']

# %%
df_df
# Out:
#              genre                    artist_name  \
# 0            opera                 giuseppe verdi
# 1            opera                giacomo puccini
# 2            opera                giacomo puccini
# 3            opera                 giuseppe verdi
# 4            opera                 giuseppe verdi
# 5            opera                 giuseppe verdi
# 6            opera                  georges bizet
# 7            opera                 giuseppe verdi
# 8            opera               vincenzo bellini
# 9            opera                    léo delibes
# 10           opera                 richard wagner
# 11           opera                  georges bizet
# 12           opera                 giuseppe verdi
# 13           opera                giacomo puccini
# 14           opera                 giuseppe verdi
# 15           opera                  georges bizet
# 16           opera                 richard wagner
# 17           opera                  georges bizet
# ...

# %%
df = df.sort_values('valence')
bad_mood = df.loc[df['valence'] != '0.0']

# %%
bad_mood
# Out:
# genre                                                           opera
# artist_name                                       frederica von stade
# track_name          pelléas et mélisande - incidental music, op.80...
# track_id                                       4mUtaOVomYIAOqAiZ0HOWu
# popularity                                                         14
# acousticness                                                    0.982
# danceability                                                    0.139
# duration_ms                                                    191107
# energy                                                         0.0232
# instrumentalness                                             3.96e-05
# key                                                                 d
# liveness                                                       0.0773
# loudness                                                      -25.384
# ...
